# %%
import langchain

# %%
langchain.__version__
# Out:
# '0.3.27'

# %%
from langchain.chains import LLMChain
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate

# %%
import os

# %%
os.environ["OPENAI_API_KEY"] = "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"

# %%
prompt_template=PromptTemplate(
    input_variables=["text"],
    template="""summarize the following text in a concise manner along with 10 quiz questions with answers at last :
    Text: {text}
    quiz:
    """
)

# %%
llm=ChatOpenAI(model="gpt-3.5-turbo")

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
quiz_chain=LLMChain(llm=llm,prompt=prompt_template)

# %%
example_text = """Text-based AI, also known as AI text generators or chatbots, are computer programs 
that generate human-like text based on prompts and large datasets. These tools, powered by Large Language Models (LLMs)
 and Natural Language Processing (NLP), can write essays, answer questions, create marketing copy, 
 and even generate computer code. Popular examples include ChatGPT, Gemini, 
and Claude, and they are widely used for content creation and increasing productivity across various fields. 
"""

# %%
quiz = quiz_chain.run(text=example_text)
print(quiz)
# Out:
# Summary: Text-based AI, also known as AI text generators or chatbots, are computer programs that generate human-like text based on prompts and large datasets, powered by Large Language Models (LLMs) and Natural Language Processing (NLP).
#
# Quiz Questions:
# 1. What are text-based AI programs also known as?
# - AI text generators or chatbots
# 2. What do text-based AI programs generate?
# - Human-like text based on prompts and large datasets
# 3. What powers text-based AI programs?
# - Large Language Models (LLMs) and Natural Language Processing (NLP)
# 4. What can text-based AI programs do?
# - Write essays, answer questions, create marketing copy, and generate computer code
# 5. Name three popular examples of text-based AI programs.
# - ChatGPT, Gemini, Claude
# 6. What are text-based AI programs widely used for?
# - Content creation and increasing productivity across various fields
# 7. What is the main function of ChatGPT and other similar programs?
# - Generating human-like text based on prompts and datasets
# 8. How are text-based AI programs powered?
# - By Large Language Models (LLMs) and Natural Language Processing (NLP)
# 9. What are some tasks that text-based AI programs can perform?
# - Writing essays, answering questions, creating marketing copy, and generating computer code
# 10. How can text-based AI programs benefit various fields?
# - By increasing productivity through content creation and automation.
